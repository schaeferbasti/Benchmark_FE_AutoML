# %% [markdown]
# # Analysis of the AMLTK Pipeline
# OpenFE-like Analysis

# %% [markdown]
# ### Imports

# %%
import os
import numpy as np

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Read Files

# %%
files = os.listdir(os.pardir + "/files")
parquet_files = []
for file in files:
    if file.endswith(".parquet") and not file.__contains__("tabular_data"):
        parquet_files.append(file)
        parquet_files.append(file)
# Out:
# ../files
# ['results_wilt_dataset_bioautoml_lgbm_classifier_pipeline_2.parquet', 'results_wilt_dataset_bioautoml_lgbm_classifier_pipeline_2.parquet', 'results_wilt_dataset_boruta_lgbm_classifier_pipeline_1.parquet', 'results_wilt_dataset_boruta_lgbm_classifier_pipeline_1.parquet', 'results_car_dataset_bioautoml_lgbm_classifier_pipeline_6.parquet', 'results_car_dataset_bioautoml_lgbm_classifier_pipeline_6.parquet', 'results_car_dataset_openfe_lgbm_classifier_pipeline_6.parquet', 'results_car_dataset_openfe_lgbm_classifier_pipeline_6.parquet', 'results_wine_quality_white_dataset_autogluon_lgbm_classifier_pipeline_4.parquet', 'results_wine_quality_white_dataset_autogluon_lgbm_classifier_pipeline_4.parquet', 'results_kr_vs_kp_dataset_autofeat_lgbm_classifier_pipeline_9.parquet', 'results_kr_vs_kp_dataset_autofeat_lgbm_classifier_pipeline_9.parquet', 'results_moneyball_dataset_autogluon_lgbm_classifier_pipeline_1.parquet', 'results_moneyball_dataset_autogluon_lgbm_classifier_pipeline_1.parquet', 'results_abalone_dataset_correlationBasedFS_lgbm_classifier_pipeline_0.parquet', 'results_abalone_dataset_correlationBasedFS_lgbm_classifier_pipeline_0.parquet', 'results_pc4_dataset_bioautoml_lgbm_classifier_pipeline_7.parquet', 'results_pc4_dataset_bioautoml_lgbm_classifier_pipeline_7.parquet', 'results_abalone_dataset_autogluon_lgbm_classifier_pipeline_4.parquet', 'results_abalone_dataset_autogluon_lgbm_classifier_pipeline_4.parquet', 'results_pc4_dataset_mljar_lgbm_classifier_pipeline_1.parquet', 'results_pc4_dataset_mljar_lgbm_classifier_pipeline_1.parquet', 'results_kr_vs_kp_dataset_openfe_lgbm_classifier_pipeline_5.parquet', 'results_kr_vs_kp_dataset_openfe_lgbm_classifier_pipeline_5.parquet', 'results_churn_dataset_bioautoml_lgbm_classifier_pipeline_4.parquet', 'results_churn_dataset_bioautoml_lgbm_classifier_pipeline_4.parquet', 'results_credit_g_dataset_mljar_lgbm_classifier_pipeline_7.parquet', 'results_credit_g_dataset_mljar_lgbm_classifier_pipeline_7.parquet', 'results_mfeat_factors_dataset_correlationBasedFS_lgbm_classifier_pipeline_9.parquet', 'results_mfeat_factors_dataset_correlationBasedFS_lgbm_classifier_pipeline_9.parquet', 'results_dna_dataset_mafese_lgbm_classifier_pipeline_9.parquet', 'results_dna_dataset_mafese_lgbm_classifier_pipeline_9.parquet', 'results_churn_dataset_featurewiz_lgbm_classifier_pipeline_6.parquet', 'results_churn_dataset_featurewiz_lgbm_classifier_pipeline_6.parquet', 'results_dna_dataset_correlationBasedFS_lgbm_classifier_pipeline_2.parquet', 'results_dna_dataset_correlationBasedFS_lgbm_classifier_pipeline_2.parquet', 'results_wilt_dataset_featurewiz_lgbm_classifier_pipeline_1.parquet', 'results_wilt_dataset_featurewiz_lgbm_classifier_pipeline_1.parquet', 'results_abalone_dataset_autofeat_lgbm_classifier_pipeline_0.parquet', 'results_abalone_dataset_autofeat_lgbm_classifier_pipeline_0.parquet', 'results_madeline_dataset_openfe_lgbm_classifier_pipeline_3.parquet', 'results_madeline_dataset_openfe_lgbm_classifier_pipeline_3.parquet', 'results_churn_dataset_autogluon_lgbm_classifier_pipeline_2.parquet', 'results_churn_dataset_autogluon_lgbm_classifier_pipeline_2.parquet', 'results_bioresponse_dataset_h2o_lgbm_classifier_pipeline_7.parquet', 'results_bioresponse_dataset_h2o_lgbm_classifier_pipeline_7.parquet', 'results_abalone_dataset_bioautoml_lgbm_classifier_pipeline_2.parquet', 'results_abalone_dataset_bioautoml_lgbm_classifier_pipeline_2.parquet', 'results_wine_quality_white_dataset_original_lgbm_classifier_pipeline_0.parquet', 'results_wine_quality_white_dataset_original_lgbm_classifier_pipeline_0.parquet', 'results_pc4_dataset_autogluon_lgbm_classifier_pipeline_1.parquet', 'results_pc4_dataset_autogluon_lgbm_classifier_pipeline_1.parquet', 'results_wine_quality_white_dataset_bioautoml_lgbm_classifier_pipeline_2.parquet', 'results_wine_quality_white_dataset_bioautoml_lgbm_classifier_pipeline_2.parquet', 'results_wilt_dataset_autogluon_lgbm_classifier_pipeline_4.parquet', 'results_wilt_dataset_autogluon_lgbm ...

# %%
df_all = pd.DataFrame(columns=['Dataset', 'Method', 'Fold', 'Value'])

for file in parquet_files:
    core_name = file[len('results_'):-len('.parquet')]
    parts = core_name.split('_')
    if parts[1] == "dataset":
        dataset = parts[0]
        method = parts[2]
        fold = parts[-1]
    elif parts[2] == "dataset":
        dataset = parts[0] + parts[1]
        method = parts[3]
        fold = parts[-1]
    elif parts[3] == "dataset":
        dataset = parts[0] + parts[1] + parts[2]
        method = parts[4]
        fold = parts[-1]
    if method == "xxx":
        print("xxx is not a valid method name")
    else:
        df = pd.read_parquet("../files/" + file)
        try:
            df = df[df['status'] == 'success']
            metric_accuracy = df["metric:roc_auc_ovo [0.0, 1.0] (maximize)"].tolist()
            value = np.average(metric_accuracy)
            df_all = df_all._append({'Dataset': dataset, 'Method': method, 'Fold': fold, 'Value': value}, ignore_index=True)
        except KeyError as e:
            print(str(e) + " for file " + str(file))
# Out:
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_autogluon_lgbm_classifier_pipeline_1.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_autogluon_lgbm_classifier_pipeline_1.parquet
# 'status' for file results_madeline_dataset_openfe_lgbm_classifier_pipeline_3.parquet
# 'status' for file results_madeline_dataset_openfe_lgbm_classifier_pipeline_3.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_h2o_lgbm_classifier_pipeline_0.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_h2o_lgbm_classifier_pipeline_0.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_h2o_lgbm_classifier_pipeline_9.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_h2o_lgbm_classifier_pipeline_9.parquet
# 'status' for file results_moneyball_dataset_correlationBasedFS_lgbm_classifier_pipeline_2.parquet
# 'status' for file results_moneyball_dataset_correlationBasedFS_lgbm_classifier_pipeline_2.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_h2o_lgbm_classifier_pipeline_9.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_h2o_lgbm_classifier_pipeline_9.parquet
# 'status' for file results_mfeat_factors_dataset_featurewiz_lgbm_classifier_pipeline_7.parquet
# 'status' for file results_mfeat_factors_dataset_featurewiz_lgbm_classifier_pipeline_7.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_mljar_lgbm_classifier_pipeline_4.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_mljar_lgbm_classifier_pipeline_4.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_h2o_lgbm_classifier_pipeline_8.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_h2o_lgbm_classifier_pipeline_8.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_blood_transfusion_service_center_dataset_original_lgbm_classifier_pipeline_4.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_blood_transfusion_service_center_dataset_original_lgbm_classifier_pipeline_4.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_blood_transfusion_service_center_dataset_mljar_lgbm_classifier_pipeline_2.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_blood_transfusion_service_center_dataset_mljar_lgbm_classifier_pipeline_2.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_bioautoml_lgbm_classifier_pipeline_3.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_bioautoml_lgbm_classifier_pipeline_3.parquet
# 'status' for file results_mfeat_factors_dataset_openfe_lgbm_classifier_pipeline_4.parquet
# 'status' for file results_mfeat_factors_dataset_openfe_lgbm_classifier_pipeline_4.parquet
# 'status' for file results_moneyball_dataset_correlationBasedFS_lgbm_classifier_pipeline_3.parquet
# 'status' for file results_moneyball_dataset_correlationBasedFS_lgbm_classifier_pipeline_3.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_bioautoml_lgbm_classifier_pipeline_8.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_bioautoml_lgbm_classifier_pipeline_8.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_original_lgbm_classifier_pipeline_1.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_original_lgbm_classifier_pipeline_1.parquet
# 'status' for file results_moneyball_dataset_correlationBasedFS_lgbm_classifier_pipeline_8.parquet
# 'status' for file results_moneyball_dataset_correlationBasedFS_lgbm_classifier_pipeline_8.parquet
# 'status' for file results_madeline_dataset_openfe_lgbm_classifier_pipeline_0.parquet
# 'status' for file results_madeline_dataset_openfe_lgbm_classifier_pipeline_0.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_mljar_lgbm_classifier_pipeline_5.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_mljar_lgbm_classifier_pipeline_5.parquet
# 'status' for file results_moneyball_dataset_correlationBasedFS_lgbm_classifier_pipeline_9.parquet
# 'status' for file results_moneyball_dataset_correlationBasedFS_lgbm_classifier_pipeline_9.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_mljar_lgbm_classifier_pipeline_0.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_mljar_lgbm_classifier_pipeline_0.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_mljar_lgbm_classifier_pipeline_2.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_mljar_lgbm_classifier_pipeline_2.parquet
# 'status' for file results_moneyball_dataset_correlationBasedFS_lgbm_classifier_pipeline_5.parquet
# 'status' for file results_moneyball_dataset_correlationBasedFS_lgbm_classifier_pipeline_5.parquet
# 'status' for file results_mfeat_factors_dataset_openfe_lgbm_classifier_pipeline_2.parquet
# 'status' for file results_mfeat_factors_dataset_openfe_lgbm_classifier_pipeline_2.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_h2o_lgbm_classifier_pipeline_7.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_h2o_lgbm_classifier_pipeline_7.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_autogluon_lgbm_classifier_pipeline_6.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_autogluon_lgbm_classifier_pipeline_6.parquet
# 'status' for file results_madeline_dataset_openfe_lgbm_classifier_pipeline_4.parquet
# 'status' for file results_madeline_dataset_openfe_lgbm_classifier_pipeline_4.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_bioautoml_lgbm_classifier_pipeline_5.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_bioautoml_lgbm_classifier_pipeline_5.parquet
# 'status' for file results_mfeat_factors_dataset_openfe_lgbm_classifier_pipeline_3.parquet
# 'status' for file results_mfeat_factors_dataset_openfe_lgbm_classifier_pipeline_3.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_bioautoml_lgbm_classifier_pipeline_4.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_bioautoml_lgbm_classifier_pipeline_4.parquet
# 'status' for file results_wilt_dataset_featurewiz_lgbm_classifier_pipeline_7.parquet
# 'status' for file results_wilt_dataset_featurewiz_lgbm_classifier_pipeline_7.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_original_lgbm_classifier_pipeline_4.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_original_lgbm_classifier_pipeline_4.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_mljar_lgbm_classifier_pipeline_3.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_mljar_lgbm_classifier_pipeline_3.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_wine_quality_white_dataset_mljar_lgbm_classifier_pipeline_1.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_wine_quality_white_dataset_mljar_lgbm_classifier_pipeline_1.parquet
# 'status' for file results_moneyball_dataset_correlationBasedFS_lgbm_classifier_pipeline_6.parquet
# 'status' for file results_moneyball_dataset_correlationBasedFS_lgbm_classifier_pipeline_6.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_bioautoml_lgbm_classifier_pipeline_6.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_bioautoml_lgbm_classifier_pipeline_6.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_wilt_dataset_featurewiz_lgbm_classifier_pipeline_5.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_wilt_dataset_featurewiz_lgbm_classifier_pipeline_5.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_wine_quality_white_dataset_autogluon_lgbm_classifier_pipeline_0.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_wine_quality_white_dataset_autogluon_lgbm_classifier_pipeline_0.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_wine_quality_white_dataset_correlationBasedFS_lgbm_classifier_pipeline_9.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_wine_quality_white_dataset_correlationBasedFS_lgbm_classifier_pipeline_9.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_mljar_lgbm_classifier_pipeline_1.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_mljar_lgbm_classifier_pipeline_1.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_wine_quality_white_dataset_h2o_lgbm_classifier_pipeline_7.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_wine_quality_white_dataset_h2o_lgbm_classifier_pipeline_7.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_h2o_lgbm_classifier_pipeline_5.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_moneyball_dataset_h2o_lgbm_classifier_pipeline_5.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_mljar_lgbm_classifier_pipeline_0.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_mljar_lgbm_classifier_pipeline_0.parquet
# 'status' for file results_moneyball_dataset_correlationBasedFS_lgbm_classifier_pipeline_7.parquet
# 'status' for file results_moneyball_dataset_correlationBasedFS_lgbm_classifier_pipeline_7.parquet
# xxx is not a valid method name
# xxx is not a valid method name
# 'status' for file results_madeline_dataset_openfe_lgbm_classifier_pipeline_6.parquet
# 'status' for file results_madeline_dataset_openfe_lgbm_classifier_pipeline_6.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_bioautoml_lgbm_classifier_pipeline_7.parquet
# 'metric:roc_auc_ovo [0.0, 1.0] (maximize)' for file results_abalone_dataset_bioautoml_lgbm_classifier_pipeline_7.parquet

# %%
# Standard Deviation
df_stddev = df_all.groupby(['Dataset', 'Method'])['Value'].std().reset_index()
df_stddev.rename(columns={'Value': 'StdDev'}, inplace=True)
df_stddev['StdDev'] = df_stddev['StdDev'].fillna(0)
# Average values
df_summary = df_all.groupby(['Dataset', 'Method'])['Value'].mean().reset_index().fillna(0)
print(df_summary)
# Out:
#               Dataset              Method     Value
# 0             abalone            autofeat  0.813284
# 1             abalone           autogluon  0.959551
# 2             abalone           bioautoml  0.933732
# 3             abalone              boruta  0.887181
# 4             abalone  correlationBasedFS  0.871825
# ..                ...                 ...       ...
# 164  winequalitywhite                 h2o  0.881967
# 165  winequalitywhite              mafese  0.497010
# 166  winequalitywhite               mljar  0.886400
# 167  winequalitywhite              openfe  0.874528
# 168  winequalitywhite            original  0.806756
#
# [169 rows x 3 columns]

# %%
# Add standard deviation to the averages values
df_summary = pd.merge(df_summary, df_stddev)
df_summary['Value_with_StdDev'] = df_summary.apply(lambda row: f"{row['Value']} ± {row['StdDev']}", axis=1)
print(df_summary)
# Out:
#               Dataset              Method     Value    StdDev  \
# 0             abalone            autofeat  0.813284  0.093089
# 1             abalone           autogluon  0.959551  0.052766
# 2             abalone           bioautoml  0.933732  0.021261
# 3             abalone              boruta  0.887181  0.048281
# 4             abalone  correlationBasedFS  0.871825  0.062477
# ..                ...                 ...       ...       ...
# 164  winequalitywhite                 h2o  0.881967  0.134722
# 165  winequalitywhite              mafese  0.497010  0.000000
# 166  winequalitywhite               mljar  0.886400  0.119438
# 167  winequalitywhite              openfe  0.874528  0.000000
# 168  winequalitywhite            original  0.806756  0.094919
#
#                              Value_with_StdDev
# 0     0.8132843117909951 ± 0.09308910011081249
# 1    0.9595507253818492 ± 0.052766378112794075
# 2    0.9337321537950015 ± 0.021260912403221022
# 3     0.8871805891212288 ± 0.04828057790817883
# 4    0.8718249558849116 ± 0.062477061863383455
# ..                                         ...
# 164     0.88196672827172 ± 0.13472188936168322
# 165                  0.49701018270630426 ± 0.0
# 166     0.8864001870388714 ± 0.119438493789624
# 167                   0.8745283937000389 ± 0.0
# 168    0.8067557216920804 ± 0.0949186275599887
#
# [169 rows x 5 columns]

# %%
# Print and write to file
pivot_table = df_summary.pivot(index='Dataset', columns='Method', values='Value_with_StdDev').fillna('Failed')
pivot_table.reset_index(inplace=True)
pivot_table.to_parquet('tabular_data.parquet')
print(tabulate(pivot_table, headers='keys', tablefmt='pretty'))
# Out:
# +----+------------------------+---------------------------------------------+-------------------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+-------------------------------------------+-------------------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+
# |    |        Dataset         |                  autofeat                   |                 autogluon                 |                 bioautoml                 |                   boruta                   |            correlationBasedFS             |                featurewiz                 |                    h2o                    |                   macfe                   |                   mafese                   |                   mljar                   |                   openfe                   |                 original                  |
# +----+------------------------+---------------------------------------------+-------------------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+-------------------------------------------+-------------------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+
# | 0  |        abalone         |  0.8132843117909951 ± 0.09308910011081249   | 0.9595507253818492 ± 0.052766378112794075 | 0.9337321537950015 ± 0.021260912403221022 |  0.8871805891212288 ± 0.04828057790817883  | 0.8718249558849116 ± 0.062477061863383455 | 0.8547477374098723 ± 0.08310818675221741  |  0.923193786596546 ± 0.03201612713013714  |                  Failed                   |          0.5069378199840331 ± 0.0          | 0.9065366690453756 ± 0.026367571328773817 |  0.7261306499658575 ± 0.04632468810063818  | 0.9210056971732782 ± 0.030340912526276066 |
# | 1  |       australian       |  0.8633481755274228 ± 0.08556542960033772   | 0.7768502496875963 ± 0.07214711169321046  | 0.9269747533297815 ± 0.01596224777771613  |  0.8806502079824351 ± 0.04221807314825225  | 0.8485029033143373 ± 0.02305478925491503  | 0.8594210428915731 ± 0.06853497574156851  | 0.7320320772623131 ± 0.09730937832305772  | 0.4997148311456968 ± 0.02936226561753587  |          0.504740603546007 ± 0.0           | 0.9105497149501564 ± 0.05310837764882408  |  0.7800878785779988 ± 0.04590054093943851  | 0.8938936071582919 ± 0.08148757384333954  |
# | 2  |      bioresponse       |                   Failed                    | 0.7530751795022829 ± 0.06878332619071999  | 0.8849653404795725 ± 0.07310113493471525  |  0.8594797528446406 ± 0.06670390769541502  |                  Failed                   | 0.8624236366543483 ± 0.061591889712881556 | 0.7558501947146562 ± 0.10105022046311662  |                  Failed                   | 0.48790899635103635 ± 0.017095611805676404 |  0.8757917643618633 ± 0.0622200766372305  |                   Failed                   |  0.8553636225506471 ± 0.106559796698931   |
# | 3  |          car           |  0.8520855810338301 ± 0.09486607515234319   | 0.8862574728813104 ± 0.04414070468522069  |  0.819605987379247 ± 0.06424509397401895  |  0.8778694601890975 ± 0.04940508157908093  | 0.6638880727709618 ± 0.024146176956729475 |  0.8628733529526128 ± 0.0583862664418084  |  0.7798535346868469 ± 0.105903811634865   |                  Failed                   |                   Failed                   | 0.8943048508515528 ± 0.06481637683271088  | 0.8097525574032547 ± 0.039817408145699174  | 0.9367295241922032 ± 0.029511192064982286 |
# | 4  |         churn          |  0.9823329231767837 ± 0.011758925609130682  |  0.9108248220682176 ± 0.0167259433522495  | 0.8458429768993561 ± 0.08519044825352967  |  0.8648305199766098 ± 0.07688004029732247  |  0.677520197754422 ± 0.05095424303884844  |  0.861470857026072 ± 0.0813879249126056   | 0.7023159204852729 ± 0.16490969224000038  |  0.505750198026308 ± 0.05122863564299052  |          0.5208394262095777 ± 0.0          | 0.8490126912325043 ± 0.08015603691605264  | 0.7757608896979898 ± 0.045252629062375496  | 0.8778292356839561 ± 0.09314440839951657  |
# | 5  |        creditg         |  0.8126620610309385 ± 0.08497032437169204   | 0.8593753504824961 ± 0.09649352509381748  |  0.7866832045615908 ± 0.0599116135253607  |  0.8561256173753944 ± 0.04167047327787476  | 0.6422571728697405 ± 0.03855123280170164  | 0.8262438042762088 ± 0.07823030172124444  | 0.7413784017468769 ± 0.09011903209161039  | 0.49243478922493483 ± 0.03531946288388128 |          0.5210920944458374 ± 0.0          | 0.8418646507279558 ± 0.05465740677946372  |  0.7514892154271998 ± 0.03329057363949128  |  0.868747065721155 ± 0.0725496959964681   |
# | 6  |          dna           | 0.9961944426136476 ± 4.4942964187031405e-06 | 0.9419270353390105 ± 0.11363661408256631  |  0.898425632119619 ± 0.09463237250552343  | 0.9742393019085619 ± 0.006284566328876221  |  0.684234827640171 ± 0.07416645461356096  | 0.8377902546279168 ± 0.10486086868978699  | 0.8790358143689078 ± 0.12707550032142675  |                  Failed                   | 0.47036130224650413 ± 0.03063928868979276  | 0.8757585614462897 ± 0.08470887860755004  |  0.8832412709329175 ± 0.1514389575984236   |  0.887737604135053 ± 0.12226702087029973  |
# | 7  |          gina          |                   Failed                    | 0.9639956330406395 ± 0.06455804093426581  | 0.9380404842533311 ± 0.07769571987080359  |   0.8883323949159843 ± 0.20113130753589    | 0.7559985060211943 ± 0.07420005722556457  |  0.909328864011625 ± 0.10672005841352646  | 0.9427428548527189 ± 0.004552471608694404 |                  Failed                   | 0.4915351946956024 ± 0.027529317839199603  | 0.9417236257133963 ± 0.07307969847578993  |                   Failed                   |  0.897604057007345 ± 0.04729775569892847  |
# | 8  | internetadvertisements |                   Failed                    | 0.9564531101984262 ± 0.07140893167418104  | 0.9777575398044762 ± 0.009471700667944581 | 0.9735907607316364 ± 0.003381103882711346  |         0.9173157337781506 ± 0.0          | 0.9071177290941448 ± 0.10597217961788381  | 0.8147009041080704 ± 0.12286610340250598  | 0.5229615346790357 ± 0.09317739889456718  |  0.5800077343846349 ± 0.12097228298300743  | 0.9214588896554821 ± 0.07853938540003727  |                   Failed                   | 0.9324826460442994 ± 0.021148335419818313 |
# | 9  |         krvskp         |  0.9581405131053256 ± 0.054484702050989674  | 0.9629756163838418 ± 0.07391469658241767  | 0.9538396409356676 ± 0.09814055110271931  | 0.9757847345614461 ± 0.0007222493855042327 | 0.7026187915875101 ± 0.10233877070532002  | 0.9534951790907031 ± 0.029134835250768095 | 0.942618829498519 ± 0.006180223216805037  |                  Failed                   |          0.4967282622469204 ± 0.0          | 0.9285018226676179 ± 0.08794010910794463  |  0.9522614522281518 ± 0.06081212453527057  |  0.9044202347133972 ± 0.0767169714221963  |
# | 10 |        madeline        |                   Failed                    |         0.6595827599356582 ± 0.0          | 0.8681355406210203 ± 0.12397310649057429  |  0.9759160003699616 ± 0.00586167908756255  | 0.7432770640500257 ± 0.08480798490639183  | 0.9021039431911028 ± 0.09784854891090743  | 0.9465183679636208 ± 0.01914397698032781  |                  Failed                   |          0.5046638249062809 ± 0.0          | 0.8358824546098459 ± 0.15614436141995452  |          0.8502410823886623 ± 0.0          | 0.8918992073076976 ± 0.04415039468573668  |
# | 11 |      mfeatfactors      |                   Failed                    | 0.9320505964402809 ± 0.08964075994444416  |  0.6277801212589992 ± 0.118935228435578   | 0.9742237012835268 ± 0.0077070681379596785 |  0.746804994645866 ± 0.07444921219002215  | 0.956997544107906 ± 0.030685872420210765  | 0.9401001147931911 ± 0.01361306142609868  |                  Failed                   |          0.5041696600083281 ± 0.0          | 0.8858110051097704 ± 0.13059979943404912  |                   Failed                   | 0.9315027212954156 ± 0.01622369529517573  |
# | 12 |       moneyball        |  0.7890953623121553 ± 0.14771750910628503   | 0.9925235112484267 ± 0.004679054990051012 |                  Failed                   |  0.8787428241653977 ± 0.05172120105625628  |  0.6960358538010742 ± 0.2300380926006467  |  0.8690124393479689 ± 0.0841703526191021  | 0.9278989564850414 ± 0.03846058924193896  |                  Failed                   |                   Failed                   | 0.8817660691921215 ± 0.08628777138442587  | 0.7521419120789339 ± 0.025914556048766055  | 0.9057124046875484 ± 0.09525402057301477  |
# | 13 |          pc4           |  0.9536417450595238 ± 0.010914955426141727  | 0.9318028060602983 ± 0.08478810293573043  |  0.905491164292151 ± 0.05875369503575752  | 0.9679830274667616 ± 0.0038493582950772684 | 0.7350917896178251 ± 0.05125896819400651  | 0.9227105996366918 ± 0.024248123486104785 | 0.9350242292659772 ± 0.013944296666148496 |  0.487994357511785 ± 0.02662467900181458  |  0.5023963359926766 ± 0.01869238825746418  | 0.9612438851847213 ± 0.014521280911707882 |  0.9155397169299193 ± 0.09642844740890354  | 0.9123137597971771 ± 0.06843604604993767  |
# | 14 |          wilt          |  0.9298836019493438 ± 0.10943319826716284   |  0.928083295327244 ± 0.07410543984225544  | 0.8898974168709858 ± 0.06914792760336458  |  0.9524671237127557 ± 0.07553457989147752  | 0.9298744420447507 ± 0.09309482575547398  | 0.920496400713258 ± 0.025518346506588064  | 0.8565112326084773 ± 0.10624374164539167  | 0.4916630054821621 ± 0.024669073678775976 |  0.4986271109962479 ± 0.03699914184646372  | 0.9767708772306554 ± 0.012634189133198232 | 0.9869275594383655 ± 0.0031014366463412457 | 0.9397870448720782 ± 0.019446360840038746 |
# | 15 |    winequalitywhite    |  0.8485698550967256 ± 0.14548990955856897   | 0.8620411768682991 ± 0.08392777715992641  |  0.7959999521728839 ± 0.1038803471027634  |  0.8622191199548047 ± 0.06722167092066068  | 0.8985861818427876 ± 0.13195047276377608  | 0.9141914273470984 ± 0.08769435976905403  |  0.88196672827172 ± 0.13472188936168322   |                  Failed                   |         0.49701018270630426 ± 0.0          |  0.8864001870388714 ± 0.119438493789624   |          0.8745283937000389 ± 0.0          |  0.8067557216920804 ± 0.0949186275599887  |
# +----+------------------------+---------------------------------------------+-------------------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+-------------------------------------------+-------------------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+--------------------------------------------+-------------------------------------------+

# %% [markdown]
# ### Boxplots

# %%
# Extract values
def extract_value(value_with_stddev):
    try:
        value, _ = value_with_stddev.split(' ± ')
        return float(value)
    except:
        return None        

pivot_table_numeric = pivot_table.set_index('Dataset').applymap(extract_value).reset_index()

# Melt DataFrame to format for seaborn
melted_df = pd.melt(pivot_table_numeric, id_vars=['Dataset'], var_name='Type', value_name='Value')

plt.figure(figsize=(10, 6))
sns.boxplot(x='Type', y='Value', data=melted_df)
plt.xlabel("Type")
plt.ylabel("Value")
plt.title("Box Plot of Values by Type")
plt.xticks(rotation=45)  # Rotate x-axis labels if necessary
plt.grid(True)
plt.tight_layout()
plt.savefig('../plots/box_plot.png')
plt.show()

# %%
# Extract values
def extract_value(value_with_stddev):
    try:
        value, _ = value_with_stddev.split(' ± ')
        return float(value)
    except:
        return None        

pivot_table_numeric = pivot_table.set_index('Dataset').applymap(extract_value).reset_index()

methods = list(pivot_table_numeric.columns[1:-1])
counts = [0] * len(methods)  # Initialize a list with the same length as the number of methods

for method_counter, method in enumerate(methods):  # Use enumerate to keep track of the index
    for i, value in enumerate(pivot_table_numeric[method].values):
        if value > pivot_table_numeric["original"].values[i]:  
            counts[method_counter] += 1  # Increment the count for the method if the condition is met

print(counts)

fig, ax = plt.subplots(figsize=(10, 6))  # Adjust figure size
ax.bar(methods, counts, width=0.6)  # Decrease the bar width to add space between bars

ax.set_xlabel("Type")
ax.set_ylabel("Count")
ax.set_xticklabels(methods, rotation=90, ha='right')
ax.grid(True)

plt.tight_layout()  # Ensure everything fits without overlap
plt.savefig('../plots/bar_chart_methods.png')
plt.show()
# Out:
# [5, 10, 7, 9, 1, 7, 8, 0, 0, 7, 4]
# /var/folders/p9/q_n4s9cj6m15m7f_8tvsd0380000gn/T/ipykernel_9541/1508477008.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(methods, rotation=90, ha='right')

# %%
# Extract values
def extract_value(value_with_stddev):
    try:
        value, _ = value_with_stddev.split(' ± ')
        return float(value)
    except:
        return None        

pivot_table_numeric = pivot_table.set_index('Dataset').applymap(extract_value).reset_index()

methods = list(pivot_table_numeric.columns[1:-1])
datasets = pivot_table_numeric["Dataset"].to_list()
counts = [0] * len(datasets) 

for dataset_counter, dataset in enumerate(datasets):
    for method in methods:
        print(pivot_table_numeric[method].iloc[dataset_counter])
        print(pivot_table_numeric["original"].iloc[dataset_counter])
        if pivot_table_numeric[method].iloc[dataset_counter] > pivot_table_numeric["original"].iloc[dataset_counter]:  
            counts[dataset_counter] += 1  

print(counts)

fig, ax = plt.subplots(figsize=(10, 6))  # Adjust figure size
ax.bar(datasets, counts, width=0.6)  # Decrease the bar width to add space between bars

ax.set_xlabel("Type")
ax.set_ylabel("Count")
ax.set_xticklabels(datasets, rotation=90, ha='right')
ax.grid(True)

plt.tight_layout()  # Ensure everything fits without overlap
plt.savefig('../plots/bar_chart_datasets.png')
plt.show()
# Out:
# 0.8132843117909951
# 0.9210056971732782
# 0.9595507253818492
# 0.9210056971732782
# 0.9337321537950015
# 0.9210056971732782
# 0.8871805891212288
# 0.9210056971732782
# 0.8718249558849116
# 0.9210056971732782
# 0.8547477374098723
# 0.9210056971732782
# 0.923193786596546
# 0.9210056971732782
# nan
# 0.9210056971732782
# 0.5069378199840331
# 0.9210056971732782
# 0.9065366690453756
# 0.9210056971732782
# 0.7261306499658575
# 0.9210056971732782
# 0.8633481755274228
# 0.8938936071582919
# 0.7768502496875963
# 0.8938936071582919
# 0.9269747533297815
# 0.8938936071582919
# 0.8806502079824351
# 0.8938936071582919
# 0.8485029033143373
# 0.8938936071582919
# 0.8594210428915731
# 0.8938936071582919
# 0.7320320772623131
# 0.8938936071582919
# 0.4997148311456968
# 0.8938936071582919
# 0.504740603546007
# 0.8938936071582919
# 0.9105497149501564
# 0.8938936071582919
# 0.7800878785779988
# 0.8938936071582919
# nan
# 0.8553636225506471
# 0.7530751795022829
# 0.8553636225506471
# 0.8849653404795725
# 0.8553636225506471
# 0.8594797528446406
# 0.8553636225506471
# nan
# 0.8553636225506471
# 0.8624236366543483
# 0.8553636225506471
# 0.7558501947146562
# 0.8553636225506471
# nan
# 0.8553636225506471
# 0.48790899635103635
# 0.8553636225506471
# 0.8757917643618633
# 0.8553636225506471
# nan
# 0.8553636225506471
# 0.8520855810338301
# 0.9367295241922032
# 0.8862574728813104
# 0.9367295241922032
# 0.819605987379247
# 0.9367295241922032
# 0.8778694601890975
# 0.9367295241922032
# 0.6638880727709618
# 0.9367295241922032
# 0.8628733529526128
# 0.9367295241922032
# 0.7798535346868469
# 0.9367295241922032
# nan
# 0.9367295241922032
# nan
# 0.9367295241922032
# 0.8943048508515528
# 0.9367295241922032
# 0.8097525574032547
# 0.9367295241922032
# 0.9823329231767837
# 0.8778292356839561
# 0.9108248220682176
# 0.8778292356839561
# 0.8458429768993561
# 0.8778292356839561
# 0.8648305199766098
# 0.8778292356839561
# 0.677520197754422
# 0.8778292356839561
# 0.861470857026072
# 0.8778292356839561
# 0.7023159204852729
# 0.8778292356839561
# 0.505750198026308
# 0.8778292356839561
# 0.5208394262095777
# 0.8778292356839561
# 0.8490126912325043
# 0.8778292356839561
# 0.7757608896979898
# 0.8778292356839561
# 0.8126620610309385
# 0.868747065721155
# 0.8593753504824961
# 0.868747065721155
# 0.7866832045615908
# 0.868747065721155
# 0.8561256173753944
# 0.868747065721155
# 0.6422571728697405
# 0.868747065721155
# 0.8262438042762088
# 0.868747065721155
# 0.7413784017468769
# 0.868747065721155
# 0.49243478922493483
# 0.868747065721155
# 0.5210920944458374
# 0.868747065721155
# 0.8418646507279558
# 0.868747065721155
# 0.7514892154271998
# 0.868747065721155
# 0.9961944426136476
# 0.887737604135053
# 0.9419270353390105
# 0.887737604135053
# 0.898425632119619
# 0.887737604135053
# 0.9742393019085619
# 0.887737604135053
# 0.684234827640171
# 0.887737604135053
# 0.8377902546279168
# 0.887737604135053
# 0.8790358143689078
# 0.887737604135053
# nan
# 0.887737604135053
# 0.47036130224650413
# 0.887737604135053
# 0.8757585614462897
# 0.887737604135053
# 0.8832412709329175
# 0.887737604135053
# nan
# 0.897604057007345
# 0.9639956330406395
# 0.897604057007345
# 0.9380404842533311
# 0.897604057007345
# 0.8883323949159843
# 0.897604057007345
# 0.7559985060211943
# 0.897604057007345
# 0.909328864011625
# 0.897604057007345
# 0.9427428548527189
# 0.897604057007345
# nan
# 0.897604057007345
# 0.4915351946956024
# 0.897604057007345
# 0.9417236257133963
# 0.897604057007345
# nan
# 0.897604057007345
# nan
# 0.9324826460442994
# 0.9564531101984262
# 0.9324826460442994
# 0.9777575398044762
# 0.9324826460442994
# 0.9735907607316364
# 0.9324826460442994
# 0.9173157337781506
# 0.9324826460442994
# 0.9071177290941448
# 0.9324826460442994
# 0.8147009041080704
# 0.9324826460442994
# 0.5229615346790357
# 0.9324826460442994
# 0.5800077343846349
# 0.9324826460442994
# 0.9214588896554821
# 0.9324826460442994
# nan
# 0.9324826460442994
# 0.9581405131053256
# 0.9044202347133972
# 0.9629756163838418
# 0.9044202347133972
# 0.9538396409356676
# 0.9044202347133972
# 0.9757847345614461
# 0.9044202347133972
# 0.7026187915875101
# 0.9044202347133972
# 0.9534951790907031
# 0.9044202347133972
# 0.942618829498519
# 0.9044202347133972
# nan
# 0.9044202347133972
# 0.4967282622469204
# 0.9044202347133972
# 0.9285018226676179
# 0.9044202347133972
# 0.9522614522281518
# 0.9044202347133972
# nan
# 0.8918992073076976
# 0.6595827599356582
# 0.8918992073076976
# 0.8681355406210203
# 0.8918992073076976
# 0.9759160003699616
# 0.8918992073076976
# 0.7432770640500257
# 0.8918992073076976
# 0.9021039431911028
# 0.8918992073076976
# 0.9465183679636208
# 0.8918992073076976
# nan
# 0.8918992073076976
# 0.5046638249062809
# 0.8918992073076976
# 0.8358824546098459
# 0.8918992073076976
# 0.8502410823886623
# 0.8918992073076976
# nan
# 0.9315027212954156
# 0.9320505964402809
# 0.9315027212954156
# 0.6277801212589992
# 0.9315027212954156
# 0.9742237012835268
# 0.9315027212954156
# 0.746804994645866
# 0.9315027212954156
# 0.956997544107906
# 0.9315027212954156
# 0.9401001147931911
# 0.9315027212954156
# nan
# 0.9315027212954156
# 0.5041696600083281
# 0.9315027212954156
# 0.8858110051097704
# 0.9315027212954156
# nan
# 0.9315027212954156
# 0.7890953623121553
# 0.9057124046875484
# 0.9925235112484267
# 0.9057124046875484
# nan
# 0.9057124046875484
# 0.8787428241653977
# 0.9057124046875484
# 0.6960358538010742
# 0.9057124046875484
# 0.8690124393479689
# 0.9057124046875484
# 0.9278989564850414
# 0.9057124046875484
# nan
# 0.9057124046875484
# nan
# 0.9057124046875484
# 0.8817660691921215
# 0.9057124046875484
# 0.7521419120789339
# 0.9057124046875484
# 0.9536417450595238
# 0.9123137597971771
# 0.9318028060602983
# 0.9123137597971771
# 0.905491164292151
# 0.9123137597971771
# 0.9679830274667616
# 0.9123137597971771
# 0.7350917896178251
# 0.9123137597971771
# 0.9227105996366918
# 0.9123137597971771
# 0.9350242292659772
# 0.9123137597971771
# 0.487994357511785
# 0.9123137597971771
# 0.5023963359926766
# 0.9123137597971771
# 0.9612438851847213
# 0.9123137597971771
# 0.9155397169299193
# 0.9123137597971771
# 0.9298836019493438
# 0.9397870448720782
# 0.928083295327244
# 0.9397870448720782
# 0.8898974168709858
# 0.9397870448720782
# 0.9524671237127557
# 0.9397870448720782
# 0.9298744420447507
# 0.9397870448720782
# 0.920496400713258
# 0.9397870448720782
# 0.8565112326084773
# 0.9397870448720782
# 0.4916630054821621
# 0.9397870448720782
# 0.4986271109962479
# 0.9397870448720782
# 0.9767708772306554
# 0.9397870448720782
# 0.9869275594383655
# 0.9397870448720782
# 0.8485698550967256
# 0.8067557216920804
# 0.8620411768682991
# 0.8067557216920804
# 0.7959999521728839
# 0.8067557216920804
# 0.8622191199548047
# 0.8067557216920804
# 0.8985861818427876
# 0.8067557216920804
# 0.9141914273470984
# 0.8067557216920804
# 0.88196672827172
# 0.8067557216920804
# nan
# 0.8067557216920804
# 0.49701018270630426
# 0.8067557216920804
# 0.8864001870388714
# 0.8067557216920804
# 0.8745283937000389
# 0.8067557216920804
# [3, 2, 4, 0, 2, 0, 4, 5, 3, 8, 3, 4, 2, 7, 3, 8]
# /var/folders/p9/q_n4s9cj6m15m7f_8tvsd0380000gn/T/ipykernel_9541/930186998.py:31: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(datasets, rotation=90, ha='right')

# %%
from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [.37, .63]
labels = ['Documentation', 'No Documentation']
explode = [0.1, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [.8, .2]
age_labels = ['Included', 'Not Included']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('Methods with a Documentation in the Benchmark')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.savefig('../plots/documentation_in_benchmark.png')
plt.show()

# %%
from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [.26, .74]
labels = ['Community', 'No Community']
explode = [0.1, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [.71, .29]
age_labels = ['Included', 'Not Included']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('Methods with a Community in the Benchmark')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.savefig('../plots/community_in_benchmark.png')
plt.show()

# %%
from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [.51, .49]
labels = ['Open-Source', 'Not Open-Source']
explode = [0.1, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [.0, .52, .48]
age_labels = ['Good', 'Neutral', 'Bad']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('Constraints of the Methods in the Benchmark')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.savefig('../plots/constraints_in_benchmark.png')
plt.show()

# %%
from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [.51, .49]
labels = ['Open-Source', 'Not Open-Source']
explode = [0.1, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [.17, .37, .46]
age_labels = ['Good', 'Neutral', 'Bad']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('Effort for including the Methods in the Benchmark')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.savefig('../plots/effort_in_benchmark.png')
plt.show()

# %%
from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [.51, .49]
labels = ['Open-Source', 'Not Open-Source']
explode = [0.1, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [.37, .63]
age_labels = ['Included', 'Not Included']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('Open-Source Methods in the Benchmark')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.savefig('../plots/open_source_in_benchmark.png')
plt.show()

# %%
from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [.51, .49]
labels = ['Open-Source', 'Not Open-Source']
explode = [0.1, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [.26, .74]
age_labels = ['Transductive', 'Inductive']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('Transductive Methods in the Benchmark')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.savefig('../plots/transductive_in_benchmark.png')
plt.show()

# %%
from matplotlib.patches import ConnectionPatch

# make figure and assign axis objects
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [.40, .60]
labels = ['Before 2021', 'After 2021']
explode = [0.1, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, explode=explode)

# bar chart parameters
age_ratios = [.0, 1.0]
age_labels = ['Included', 'Not Included']
bottom = 1
width = .2

# Adding from the top matches the legend.
for j, (height, label) in enumerate(reversed([*zip(age_ratios, age_labels)])):
    bottom -= height
    bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
                 alpha=0.1 + 0.25 * j)
    ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='center')

ax2.set_title('Included old Methods in the Benchmark')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
theta1, theta2 = wedges[0].theta1, wedges[0].theta2
center, r = wedges[0].center, wedges[0].r
bar_height = sum(age_ratios)

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = r * np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
con.set_linewidth(4)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = r * np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(-width / 2, 0), coordsA=ax2.transData,
                      xyB=(x, y), coordsB=ax1.transData)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(4)

plt.savefig('../plots/year_in_benchmark.png')
plt.show()
